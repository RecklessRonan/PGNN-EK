# %%
import pandas as pd 
import javalang
from javalang.ast import Node
from tqdm import tqdm

# %%
java_api_url = '/data/code/represent-code-in-human/data/java_api.csv'
java_api = pd.read_csv(java_api_url, header=0, encoding='utf-8')
java_api['index_name'] = java_api['index_name'].apply(str)
java_api
# Out:
#                  index_name  \
# 0                         a
# 1                         A
# 2                         A
# 3                         A
# 4                         A
# ...                     ...
# 51185  _write(OutputStream)
# 51186  _write(OutputStream)
# 51187  _write(OutputStream)
# 51188  _write(OutputStream)
# 51189  _write(OutputStream)
#
#                                        index_description  \
# 0         Variable in class java.awt.AWTEventMulticaster
# 1      Static variable in class java.awt.PageAttribut...
# 2      Static variable in class javax.print.attribute...
# 3      Static variable in class javax.print.attribute...
# 4      Static variable in class javax.swing.text.html...
# ...                                                  ...
# 51185  Method in class org.omg.PortableInterceptor.IO...
# 51186  Method in class org.omg.PortableInterceptor.Ob...
# 51187  Method in class org.omg.PortableInterceptor.Ob...
# 51188  Method in class org.omg.PortableInterceptor.Ob...
# 51189  Method in class org.omg.PortableServer.Servant...
#
#                                       method_description
# 0                                                   None
# 1      The MediaType instance for Engineering A, 8 1/...
# 2      Specifies the engineering A size, 8.5 inch by ...
# 3                                               A size .
# 4                                                   None
# ...                                                  ...
# 51185                                               None
# 51186                                               None
# 51187                                               None
# 51188                                               None
# 51189                                               None
#
# [51190 rows x 3 columns]

# %%
# use javalang to generate ASTs and depth-first traverse to generate ast nodes corpus
def get_token(node):
    token = ''
    if isinstance(node, str):
        token = node
    elif isinstance(node, set):
        token = 'Modifier'
    elif isinstance(node, Node):
        token = node.__class__.__name__
    return token


def get_child(root):
    if isinstance(root, Node):
        children = root.children
    elif isinstance(root, set):
        children = list(root)
    else:
        children = []

    def expand(nested_list):
        for item in nested_list:
            if isinstance(item, list):
                yield from expand(item)
            elif item:
                yield item

    return list(expand(children))


def get_sequence(node, sequence, api_sequence):
    token, children = get_token(node), get_child(node)
    sequence.append(token)
    if token == 'MethodInvocation':
        api = [get_token(child) for child in children if not get_child(child)]
        # api_sequence.append(' '.join(api))
        if len(api) > 1:
            api_sequence.append(api[-1])
    for child in children:
        get_sequence(child, sequence, api_sequence)


def parse_program(func):
    tokens = javalang.tokenizer.tokenize(func)
    parser = javalang.parser.Parser(tokens)
    return parser.parse_member_declaration()

# %%
def api_match(api_sequence, java_api):
    description_sequence = []
    for api in api_sequence:
        loc = java_api.loc[java_api['index_name'].str.contains(api, case=True)]
        if not loc.empty:
            description = loc['method_description'].iloc[0]
            if description != 'None':
                description_sequence.append(description)
    return description_sequence

# %% [markdown]
# Code Clone Detection

# %%
raw_code_url = '/data/dataset/CodeXGLUE/Code-Code/Clone-detection-BigCloneBench/dataset/data.jsonl'
raw_code = pd.read_json(path_or_buf=raw_code_url, lines=True)

# %%
raw_code

# %%
raw_code['func'][1]

# %%
from tqdm import tqdm

ast_sequence = []
description_sequence = []
for i in tqdm(range(len(raw_code))):
    sequence = []
    api_sequence = []    
    get_sequence(parse_program(raw_code['func'][i]), sequence, api_sequence)
    ast_sequence.append(' '.join(sequence))     
    api_sequence = list(set(api_sequence)) 
    # print('api_sequence', api_sequence)
    description = '\n'.join(api_match(api_sequence, java_api))
    # print('description', description)   
    description_sequence.append(description)

# %%
raw_code['ast'] = ast_sequence
raw_code['des'] = description_sequence
raw_code['ast_des'] = raw_code['ast'] + ' ' + raw_code['des']

# %%
raw_code

# %%
raw_code.to_json(path_or_buf='/data/dataset/CodeXGLUE/Code-Code/Clone-detection-BigCloneBench/dataset/data_enhanced.jsonl', orient='records', lines=True)

# %% [markdown]
# Code Summarization

# %%
TRAIN_DIR = '/data/code/represent-code-in-human/data/code-summarization-new/train.jsonl'
VALID_DIR = '/data/code/represent-code-in-human/data/code-summarization-new/valid.jsonl'
TEST_DIR = '/data/code/represent-code-in-human/data/code-summarization-new/test.jsonl'

# %%
# read dataset
train_data = pd.read_json(path_or_buf=TRAIN_DIR, lines=True)
valid_data = pd.read_json(path_or_buf=VALID_DIR, lines=True)
test_data = pd.read_json(path_or_buf=TEST_DIR, lines=True)

# %%
train_data = train_data.sample(random_state=555, frac=1)
valid_data = valid_data.sample(random_state=555, frac=1)
test_data = test_data.sample(random_state=555, frac=1)

# %%
train_data
# Out:
#                                  repo  \
# 44793                b3dgs/lionengine
# 114654                 nguyenq/tess4j
# 50192             hazelcast/hazelcast
# 63791               Netflix/conductor
# 61049   deeplearning4j/deeplearning4j
# ...                               ...
# 75158       facebookarchive/hadoop-20
# 59972          apache/incubator-druid
# 156705          classgraph/classgraph
# 15337                 exoplatform/jcr
# 4782              openengsb/openengsb
#
#                                                      path  \
# 44793   lionengine-core/src/main/java/com/b3dgs/lionen...
# 114654  src/main/java/net/sourceforge/tess4j/util/Util...
# 50192   hazelcast/src/main/java/com/hazelcast/cp/inter...
# 63791   core/src/main/java/com/netflix/conductor/servi...
# 61049   nd4j/nd4j-backends/nd4j-api-parent/nd4j-api/sr...
# ...                                                   ...
# 75158   src/contrib/hive-streaming/src/java/org/apache...
# 59972   extendedset/src/main/java/org/apache/druid/ext...
# 156705  src/main/java/io/github/classgraph/ClassTypeSi...
# 15337   exo.jcr.ext.services/src/main/java/org/exoplat...
# 4782    components/edbi/hook/src/main/java/org/openeng...
#
#                                     func_name  \
# 44793                    UtilMath.getDistance
# 114654                  Utils.getConstantName
# 50192                   RaftSemaphore.acquire
# 63791               TaskServiceImpl.batchPoll
# 61049   WorkspaceUtils.assertNoWorkspacesOpen
# ...                                       ...
# 75158           StreamJob.setUserJobConfProps
# 59972                    ConciseSet.trimZeros
# 156705               ClassTypeSignature.parse
# 15337             GroupHandlerImpl.postDelete
# 4782               CommitConverter.mapByClass
#
#                                           original_string language  \
# 44793   public static double getDistance(double x1, do...     java
# 114654  public static String getConstantName(Object va...     java
# 50192   AcquireResult acquire(AcquireInvocationKey key...     java
# 63791   @Service\n    public List<Task> batchPoll(Stri...     java
# 61049   public static void assertNoWorkspacesOpen(Stri...     java
# ...                                                   ...      ...
# 75158   protected void setUserJobConfProps(boolean doE...     java
# 59972   private void trimZeros()\r\n  {\r\n    // loop...     java
# 156705  static ClassTypeSignature parse(final String t...     java
# 15337   private void postDelete(Group group) throws Ex...     java
# 4782    protected Map<Class<?>, List<OpenEngSBModel>> ...     java
#
#                                                      code  \
# 44793   public static double getDistance(double x1, do...
# 114654  public static String getConstantName(Object va...
# 50192   AcquireResult acquire(AcquireInvocationKey key...
# 63791   @Service\n    public List<Task> batchPoll(Stri...
# 61049   public static void assertNoWorkspacesOpen(Stri...
# ...                                                   ...
# 75158   protected void setUserJobConfProps(boolean doE...
# 59972   private void trimZeros()\r\n  {\r\n    // loop...
# 156705  static ClassTypeSignature parse(final String t...
# 15337   private void postDelete(Group group) throws Ex...
# 4782    protected Map<Class<?>, List<OpenEngSBModel>> ...
#
#                                               code_tokens  \
# 44793   [public, static, double, getDistance, (, doubl...
# 114654  [public, static, String, getConstantName, (, O...
# 50192   [AcquireResult, acquire, (, AcquireInvocationK...
# 63791   [@, Service, public, List, <, Task, >, batchPo...
# 61049   [public, static, void, assertNoWorkspacesOpen,...
# ...                                                   ...
# 75158   [protected, void, setUserJobConfProps, (, bool...
# 59972   [private, void, trimZeros, (, ), {, // loop ov...
# 156705  [static, ClassTypeSignature, parse, (, final, ...
# 15337   [private, void, postDelete, (, Group, group, )...
# 4782    [protected, Map, <, Class, <, ?, >, ,, List, <...
#
#                                                 docstring  \
# 44793   Get distance from point to area.\n\n@param x1 ...
# 114654  Gets user-friendly name of the public static f...
# 50192   Assigns permits to the endpoint, if sufficient...
# 63791   Batch Poll for a task of a certain type.\n\n@p...
# 61049   Assert that no workspaces are currently open\n...
# ...                                                   ...
# 75158   This method sets the user jobconf variable spe...
# 59972                              Removes trailing zeros
# 156705  Parse a class type signature or class type des...
# 15337   Notifying listeners after group deletion.\n\n@...
# 4782    Groups all models in the given collection by t...
#
#                                          docstring_tokens  \
# 44793           [Get, distance, from, point, to, area, .]
# 114654  [Gets, user, -, friendly, name, of, the, publi...
# 50192   [Assigns, permits, to, the, endpoint, if, suff...
# 63791   [Batch, Poll, for, a, task, of, a, certain, ty...
# 61049   [Assert, that, no, workspaces, are, currently,...
# ...                                                   ...
# 75158   [This, method, sets, the, user, jobconf, varia...
# 59972                          [Removes, trailing, zeros]
# 156705  [Parse, a, class, type, signature, or, class, ...
# 15337   [Notifying, listeners, after, group, deletion, .]
# 4782    [Groups, all, models, in, the, given, collecti...
#
#                                              sha  \
# 44793   cac3d5578532cf11724a737b9f09e71bf9995ab2
# 114654  cfcd4a8a44042f150b4aaf7bdf5ffc485a2236e1
# 50192   8c4bc10515dbbfb41a33e0302c0caedf3cda1baf
# 63791   78fae0ed9ddea22891f9eebb96a2ec0b2783dca0
# 61049   effce52f2afd7eeb53c5bcca699fcd90bd06822f
# ...                                          ...
# 75158   2a29bc6ecf30edb1ad8dbde32aa49a317b4d44f4
# 59972   f776b9408962b9006cfcfe4d6c1794751972cc8e
# 156705  c8c8b2ca1eb76339f69193fdac33d735c864215c
# 15337   3e7f9ee1b5683640d73a4316fb4b0ad5eac5b8a2
# 4782    d39058000707f617cd405629f9bc7f17da7b414a
#
#                                                       url partition
# 44793   https://github.com/b3dgs/lionengine/blob/cac3d...     train
# 114654  https://github.com/nguyenq/tess4j/blob/cfcd4a8...     train
# 50192   https://github.com/hazelcast/hazelcast/blob/8c...     train
# 63791   https://github.com/Netflix/conductor/blob/78fa...     train
# 61049   https://github.com/deeplearning4j/deeplearning...     train
# ...                                                   ...       ...
# 75158   https://github.com/facebookarchive/hadoop-20/b...     train
# 59972   https://github.com/apache/incubator-druid/blob...     train
# 156705  https://github.com/classgraph/classgraph/blob/...     train
# 15337   https://github.com/exoplatform/jcr/blob/3e7f9e...     train
# 4782    https://github.com/openengsb/openengsb/blob/d3...     train
#
# [164814 rows x 12 columns]

# %%
def get_ast_and_description(data):
    description_sequence = []
    ast_sequence = []
    ast_sum = 0
    description_sum = 0
    data_size = len(data)
    for i in tqdm(range(data_size)):
        sequence = []
        api_sequence = []    
        get_sequence(parse_program(data['code'].iloc[i]), sequence, api_sequence)
        ast = ' '.join(sequence)
        ast_sequence.append(ast) 
        ast_sum += len(ast.split(' '))

        api_sequence = list(set(api_sequence)) 
        description = ' '.join(api_match(api_sequence, java_api)) 
        description_sequence.append(description) 
        description_sum += len(description.split(' '))
    print('ast average length', ast_sum/data_size)
    print('description average length', description_sum/data_size)
    return description_sequence, ast_sequence

# %%
valid_description, valid_ast = get_ast_and_description(valid_data)
test_description, test_ast = get_ast_and_description(test_data)
# Out:
# 100%|██████████| 5179/5179 [05:50<00:00, 14.99it/s]
#   0%|          | 3/10952 [00:00<06:56, 26.30it/s]
# ast average length 83.33770998262213
# description average length 23.19810774280749
# 100%|██████████| 10952/10952 [13:37<00:00,  8.60it/s]
# ast average length 93.25054784514244
# description average length 24.801406135865594

# %%
valid_data['des'] = valid_description
valid_data['ast'] = valid_ast
valid_data['ast_des'] = valid_data['ast'] + ' ' + valid_data['des']

test_data['des'] = test_description
test_data['ast'] = test_ast
test_data['ast_des'] = test_data['ast'] + ' ' + test_data['des']

# %%
# train_data.to_json(path_or_buf='/data/code/represent-code-in-human/data/code-summarization-enhanced-middle/train.jsonl',
#                      orient='records', lines=True)
# valid_data.to_json(path_or_buf='/data/code/represent-code-in-human/data/code-summarization-enhanced-middle/valid.jsonl',
#                      orient='records', lines=True)
# test_data.to_json(path_or_buf='/data/code/represent-code-in-human/data/code-summarization-enhanced-middle/test.jsonl',
#                      orient='records', lines=True)

# %%
test_data
# Out:
#                                 repo  \
# 4336                 Unidata/thredds
# 3258      orientechnologies/orientdb
# 10885            intellimate/IzouSDK
# 2928      orientechnologies/orientdb
# 2371        streamsets/datacollector
# ...                              ...
# 6694                      Axway/iron
# 7549   lessthanoptimal/GeoRegression
# 10820            intellimate/IzouSDK
# 9249         jboss/jboss-common-core
# 4782                 Unidata/thredds
#
#                                                     path  \
# 4336     cdm/src/main/java/ucar/unidata/util/Format.java
# 3258   core/src/main/java/com/orientechnologies/orien...
# 10885  src/main/java/org/intellimate/izou/sdk/framewo...
# 2928   object/src/main/java/com/orientechnologies/ori...
# 2371   cluster-bootstrap-api/src/main/java/com/stream...
# ...                                                  ...
# 6694   iron-core/src/main/java/io/axway/iron/core/int...
# 7549   main/src/georegression/geometry/UtilLine2D_F64...
# 10820  src/main/java/org/intellimate/izou/sdk/framewo...
# 9249   src/main/java/org/jboss/util/property/Property...
# 4782   dap4/d4lib/src/main/java/dap4/dap4lib/DSPPrint...
#
#                                           func_name  \
# 4336                                     Format.tab
# 3258   OBinarySerializerFactory.getObjectSerializer
# 10885                              TrackInfo.export
# 2928   ODocumentFieldHandlingStrategyFactory.create
# 2371                 BootstrapClusterStreaming.main
# ...                                             ...
# 6694                    StorePersistence.loadStores
# 7549                         UtilLine2D_F64.convert
# 10820                  PresenceConstant.setPresence
# 9249                                   Property.set
# 4782               DSPPrinter.printCompoundInstance
#
#                                          original_string language  \
# 4336   public static void tab(StringBuffer sbuff, int...     java
# 3258   @SuppressWarnings("unchecked")\n  public <T> O...     java
# 10885  public HashMap<String, Object> export() {\n   ...     java
# 2928   public ODocumentFieldHandlingStrategy create(i...     java
# 2371   public static void main(String[] args) throws ...     java
# ...                                                  ...      ...
# 6694   Optional<BigInteger> loadStores(Function<Strin...     java
# 7549   public static LinePolar2D_F64 convert( LineGen...     java
# 10820  public void setPresence(boolean present) {\n  ...     java
# 9249   public static String set(String name, String v...     java
# 4782   protected void\n    printCompoundInstance(Data...     java
#
#                                                     code  \
# 4336   public static void tab(StringBuffer sbuff, int...
# 3258   @SuppressWarnings("unchecked")\n  public <T> O...
# 10885  public HashMap<String, Object> export() {\n   ...
# 2928   public ODocumentFieldHandlingStrategy create(i...
# 2371   public static void main(String[] args) throws ...
# ...                                                  ...
# 6694   Optional<BigInteger> loadStores(Function<Strin...
# 7549   public static LinePolar2D_F64 convert( LineGen...
# 10820  public void setPresence(boolean present) {\n  ...
# 9249   public static String set(String name, String v...
# 4782   protected void\n    printCompoundInstance(Data...
#
#                                              code_tokens  \
# 4336   [public, static, void, tab, (, StringBuffer, s...
# 3258   [@, SuppressWarnings, (, "unchecked", ), publi...
# 10885  [public, HashMap, <, String, ,, Object, >, exp...
# 2928   [public, ODocumentFieldHandlingStrategy, creat...
# 2371   [public, static, void, main, (, String, [, ], ...
# ...                                                  ...
# 6694   [Optional, <, BigInteger, >, loadStores, (, Fu...
# 7549   [public, static, LinePolar2D_F64, convert, (, ...
# 10820  [public, void, setPresence, (, boolean, presen...
# 9249   [public, static, String, set, (, String, name,...
# 4782   [protected, void, printCompoundInstance, (, Da...
#
#                                                docstring  \
# 4336   Blank fill sbuff with blanks, until position t...
# 3258   Obtain OBinarySerializer realization for the O...
# 10885  exports the TrackInfo to a Hashmap\n@return a ...
# 2928   Creates a new instance of the requested strate...
# 2371   Bootstrapping the Driver which starts a Spark ...
# ...                                                  ...
# 6694   Load the stores.\n\n@param entityStoresByStore...
# 7549   Converts a line from general to polar.\n\n@par...
# 10820  sets the presence\n@param present true for pre...
# 9249   Set a property\n\n@param name    Property name...
# 4782   Print a single structure or sequence or record...
#
#                                         docstring_tokens  \
# 4336   [Blank, fill, sbuff, with, blanks, until, posi...
# 3258   [Obtain, OBinarySerializer, realization, for, ...
# 10885          [exports, the, TrackInfo, to, a, Hashmap]
# 2928   [Creates, a, new, instance, of, the, requested...
# 2371   [Bootstrapping, the, Driver, which, starts, a,...
# ...                                                  ...
# 6694                              [Load, the, stores, .]
# 7549    [Converts, a, line, from, general, to, polar, .]
# 10820                              [sets, the, presence]
# 9249                                  [Set, a, property]
# 4782   [Print, a, single, structure, or, sequence, or...
#
#                                             sha  \
# 4336   d2d68f9eee87f345625211324d71d5dc3e162ee1
# 3258   d970b12033f0462f0239ea0ad8ed41207e6e26f1
# 10885  bc8705ad48a6ca12a722f2b787be435949fa5d08
# 2928   d970b12033f0462f0239ea0ad8ed41207e6e26f1
# 2371   ea63245ea14d59d5229248387f0628f46131eae5
# ...                                         ...
# 6694   387ec6d43d2353f857d510dd29f93a06a8db9069
# 7549   c067cd44a4e95bd826119f6e658bd82386ef289f
# 10820  bc8705ad48a6ca12a722f2b787be435949fa5d08
# 9249   c191bb18db83fa106c6913cf34ed47989b65dc97
# 4782   d2d68f9eee87f345625211324d71d5dc3e162ee1
#
#                                                      url partition  \
# 4336   https://github.com/Unidata/thredds/blob/d2d68f...      test
# 3258   https://github.com/orientechnologies/orientdb/...      test
# 10885  https://github.com/intellimate/IzouSDK/blob/bc...      test
# 2928   https://github.com/orientechnologies/orientdb/...      test
# 2371   https://github.com/streamsets/datacollector/bl...      test
# ...                                                  ...       ...
# 6694   https://github.com/Axway/iron/blob/387ec6d43d2...      test
# 7549   https://github.com/lessthanoptimal/GeoRegressi...      test
# 10820  https://github.com/intellimate/IzouSDK/blob/bc...      test
# 9249   https://github.com/jboss/jboss-common-core/blo...      test
# 4782   https://github.com/Unidata/thredds/blob/d2d68f...      test
#
#                                                      des  \
# 4336   Sets the length of this file. Returns the curr...
# 3258     Adds a new DropTargetListener (UNICAST SOURCE).
# 10885  Called by the context acceptor to process a to...
# 2928   Adds a new DropTargetListener (UNICAST SOURCE)...
# 2371   Awaits termination of the group. Determines th...
# ...                                                  ...
# 6694   Adds component-listener-a with component-liste...
# 7549   Returns the correctly rounded positive square ...
# 10820
# 9249   Sets the system property indicated by the spec...
# 4782   Adds a new DropTargetListener (UNICAST SOURCE)...
#
#                                                      ast  \
# 4336   MethodDeclaration Modifier public static tab F...
# 3258   MethodDeclaration Modifier public Annotation S...
# 10885  MethodDeclaration Modifier public ReferenceTyp...
# 2928   MethodDeclaration Modifier public ReferenceTyp...
# 2371   MethodDeclaration Modifier public static main ...
# ...                                                  ...
# 6694   MethodDeclaration ReferenceType Optional TypeA...
# 7549   MethodDeclaration Modifier public static Refer...
# 10820  MethodDeclaration Modifier public setPresence ...
# 9249   MethodDeclaration Modifier public static Refer...
# 4782   MethodDeclaration Modifier protected printComp...
#
#                                                  ast_des
# 4336   MethodDeclaration Modifier public static tab F...
# 3258   MethodDeclaration Modifier public Annotation S...
# 10885  MethodDeclaration Modifier public ReferenceTyp...
# 2928   MethodDeclaration Modifier public ReferenceTyp...
# 2371   MethodDeclaration Modifier public static main ...
# ...                                                  ...
# 6694   MethodDeclaration ReferenceType Optional TypeA...
# 7549   MethodDeclaration Modifier public static Refer...
# 10820  MethodDeclaration Modifier public setPresence ...
# 9249   MethodDeclaration Modifier public static Refer...
# 4782   MethodDeclaration Modifier protected printComp...
#
# [10952 rows x 15 columns]

# %%
valid_data.to_json(path_or_buf='/data/code/represent-code-in-human/data/code-summarization-enhanced-full/valid.jsonl',
                     orient='records', lines=True)
test_data.to_json(path_or_buf='/data/code/represent-code-in-human/data/code-summarization-enhanced-full/test.jsonl',
                     orient='records', lines=True)

# %%
train_description, train_ast = get_ast_and_description(train_data)
train_data['des'] = train_description
train_data['ast'] = train_ast
train_data['ast_des'] = train_data['ast'] + ' ' + train_data['des']
train_data.to_json(path_or_buf='/data/code/represent-code-in-human/data/code-summarization-enhanced-full/train.jsonl',
                     orient='records', lines=True)

# %% [markdown]
# multiprocessing test

# %%
from multiprocessing import Process, cpu_count, Manager, Pool 
import os

# %%
def multi_get_ast_and_des(l, i):
    sequence = []
    api_sequence = []    
    get_sequence(parse_program(train_data['code'].iloc[i]), sequence, api_sequence)
    ast = ' '.join(sequence)
    api_sequence = list(set(api_sequence)) 
    des = ' '.join(api_match(api_sequence, java_api)) 
    d = {'ast': ast, 'des': des, 'i': i}
    l.append(d)
    # print('i', i, 'ast', ast, 'des', des)

# %%
manager = Manager()
data_size = len(train_data)
l = manager.list()
p = Pool(processes=20)
for i in range(data_size):
    p.apply_async(multi_get_ast_and_des, (l, i))
p.close()
p.join()

# %%
train_ast = []
train_des = []
train_i = []
for d in l[:]:
    train_ast.append(d['ast'])
    train_des.append(d['des'])
    train_i.append(d['i'])

# %%
len(train_i)
# Out:
# 164814

# %%
train_dict = {'ast': train_ast, 'des': train_des, 'i': train_i}
train_df = pd.DataFrame.from_dict(train_dict)

# %%
train_df
# Out:
#                                                       ast  \
# 0       MethodDeclaration Modifier public static Basic...
# 1       MethodDeclaration Modifier public static Basic...
# 2       MethodDeclaration Modifier public static TypeP...
# 3       MethodDeclaration Modifier private BasicType i...
# 4       MethodDeclaration Modifier public Annotation O...
# ...                                                   ...
# 164809  MethodDeclaration Modifier public ReferenceTyp...
# 164810  MethodDeclaration Modifier public final BasicT...
# 164811  MethodDeclaration Modifier private addNode For...
# 164812  MethodDeclaration Modifier public update Forma...
# 164813  MethodDeclaration Modifier public static Refer...
#
#                                                       des       i
# 0                                                               5
# 1                            Compares two boolean values.       0
# 2                                                               9
# 3                                                              12
# 4       Removes all resource bundles from the cache th...       8
# ...                                                   ...     ...
# 164809  The InputStream object that will be returned b...  163869
# 164810                                                     164325
# 164811  Retrieves the value of the designated JDBC CHA...  164007
# 164812  Returns the raw keycode of this MenuShortcut. ...  164201
# 164813                  Reads and returns one input byte.  164791
#
# [164814 rows x 3 columns]

# %%
train_df = train_df.sort_values(by=['i']).reset_index(drop=True)
train_df
# Out:
#                                                       ast  \
# 0       MethodDeclaration Modifier public static Basic...
# 1       MethodDeclaration Modifier public static Refer...
# 2       MethodDeclaration ReferenceType AcquireResult ...
# 3       MethodDeclaration Modifier public Annotation S...
# 4       MethodDeclaration Modifier public static asser...
# ...                                                   ...
# 164809  MethodDeclaration Modifier protected setUserJo...
# 164810  MethodDeclaration Modifier private trimZeros L...
# 164811  MethodDeclaration Modifier static ReferenceTyp...
# 164812  MethodDeclaration Modifier private postDelete ...
# 164813  MethodDeclaration Modifier protected Reference...
#
#                                                       des       i
# 0                            Compares two boolean values.       0
# 1       Adds a new DropTargetListener (UNICAST SOURCE)...       1
# 2       Adds a new DropTargetListener (UNICAST SOURCE)...       2
# 3       Polls this queue to see if a reference object ...       3
# 4       Returns a list of MemoryManagerMXBean objects ...       4
# ...                                                   ...     ...
# 164809  Adds a new DropTargetListener (UNICAST SOURCE)...  164809
# 164810                                                     164810
# 164811  Returns an empty list (immutable). Provides th...  164811
# 164812                                                     164812
# 164813          Returns the runtime class of this Object.  164813
#
# [164814 rows x 3 columns]

# %%
train_data['ast'] = train_df['ast'].to_list()
train_data['des'] = train_df['des'].to_list()
train_data['ast_des'] = train_data['ast'] + ' ' + train_data['des']
train_data
# Out:
#                                  repo  \
# 44793                b3dgs/lionengine
# 114654                 nguyenq/tess4j
# 50192             hazelcast/hazelcast
# 63791               Netflix/conductor
# 61049   deeplearning4j/deeplearning4j
# ...                               ...
# 75158       facebookarchive/hadoop-20
# 59972          apache/incubator-druid
# 156705          classgraph/classgraph
# 15337                 exoplatform/jcr
# 4782              openengsb/openengsb
#
#                                                      path  \
# 44793   lionengine-core/src/main/java/com/b3dgs/lionen...
# 114654  src/main/java/net/sourceforge/tess4j/util/Util...
# 50192   hazelcast/src/main/java/com/hazelcast/cp/inter...
# 63791   core/src/main/java/com/netflix/conductor/servi...
# 61049   nd4j/nd4j-backends/nd4j-api-parent/nd4j-api/sr...
# ...                                                   ...
# 75158   src/contrib/hive-streaming/src/java/org/apache...
# 59972   extendedset/src/main/java/org/apache/druid/ext...
# 156705  src/main/java/io/github/classgraph/ClassTypeSi...
# 15337   exo.jcr.ext.services/src/main/java/org/exoplat...
# 4782    components/edbi/hook/src/main/java/org/openeng...
#
#                                     func_name  \
# 44793                    UtilMath.getDistance
# 114654                  Utils.getConstantName
# 50192                   RaftSemaphore.acquire
# 63791               TaskServiceImpl.batchPoll
# 61049   WorkspaceUtils.assertNoWorkspacesOpen
# ...                                       ...
# 75158           StreamJob.setUserJobConfProps
# 59972                    ConciseSet.trimZeros
# 156705               ClassTypeSignature.parse
# 15337             GroupHandlerImpl.postDelete
# 4782               CommitConverter.mapByClass
#
#                                           original_string language  \
# 44793   public static double getDistance(double x1, do...     java
# 114654  public static String getConstantName(Object va...     java
# 50192   AcquireResult acquire(AcquireInvocationKey key...     java
# 63791   @Service\n    public List<Task> batchPoll(Stri...     java
# 61049   public static void assertNoWorkspacesOpen(Stri...     java
# ...                                                   ...      ...
# 75158   protected void setUserJobConfProps(boolean doE...     java
# 59972   private void trimZeros()\r\n  {\r\n    // loop...     java
# 156705  static ClassTypeSignature parse(final String t...     java
# 15337   private void postDelete(Group group) throws Ex...     java
# 4782    protected Map<Class<?>, List<OpenEngSBModel>> ...     java
#
#                                                      code  \
# 44793   public static double getDistance(double x1, do...
# 114654  public static String getConstantName(Object va...
# 50192   AcquireResult acquire(AcquireInvocationKey key...
# 63791   @Service\n    public List<Task> batchPoll(Stri...
# 61049   public static void assertNoWorkspacesOpen(Stri...
# ...                                                   ...
# 75158   protected void setUserJobConfProps(boolean doE...
# 59972   private void trimZeros()\r\n  {\r\n    // loop...
# 156705  static ClassTypeSignature parse(final String t...
# 15337   private void postDelete(Group group) throws Ex...
# 4782    protected Map<Class<?>, List<OpenEngSBModel>> ...
#
#                                               code_tokens  \
# 44793   [public, static, double, getDistance, (, doubl...
# 114654  [public, static, String, getConstantName, (, O...
# 50192   [AcquireResult, acquire, (, AcquireInvocationK...
# 63791   [@, Service, public, List, <, Task, >, batchPo...
# 61049   [public, static, void, assertNoWorkspacesOpen,...
# ...                                                   ...
# 75158   [protected, void, setUserJobConfProps, (, bool...
# 59972   [private, void, trimZeros, (, ), {, // loop ov...
# 156705  [static, ClassTypeSignature, parse, (, final, ...
# 15337   [private, void, postDelete, (, Group, group, )...
# 4782    [protected, Map, <, Class, <, ?, >, ,, List, <...
#
#                                                 docstring  \
# 44793   Get distance from point to area.\n\n@param x1 ...
# 114654  Gets user-friendly name of the public static f...
# 50192   Assigns permits to the endpoint, if sufficient...
# 63791   Batch Poll for a task of a certain type.\n\n@p...
# 61049   Assert that no workspaces are currently open\n...
# ...                                                   ...
# 75158   This method sets the user jobconf variable spe...
# 59972                              Removes trailing zeros
# 156705  Parse a class type signature or class type des...
# 15337   Notifying listeners after group deletion.\n\n@...
# 4782    Groups all models in the given collection by t...
#
#                                          docstring_tokens  \
# 44793           [Get, distance, from, point, to, area, .]
# 114654  [Gets, user, -, friendly, name, of, the, publi...
# 50192   [Assigns, permits, to, the, endpoint, if, suff...
# 63791   [Batch, Poll, for, a, task, of, a, certain, ty...
# 61049   [Assert, that, no, workspaces, are, currently,...
# ...                                                   ...
# 75158   [This, method, sets, the, user, jobconf, varia...
# 59972                          [Removes, trailing, zeros]
# 156705  [Parse, a, class, type, signature, or, class, ...
# 15337   [Notifying, listeners, after, group, deletion, .]
# 4782    [Groups, all, models, in, the, given, collecti...
#
#                                              sha  \
# 44793   cac3d5578532cf11724a737b9f09e71bf9995ab2
# 114654  cfcd4a8a44042f150b4aaf7bdf5ffc485a2236e1
# 50192   8c4bc10515dbbfb41a33e0302c0caedf3cda1baf
# 63791   78fae0ed9ddea22891f9eebb96a2ec0b2783dca0
# 61049   effce52f2afd7eeb53c5bcca699fcd90bd06822f
# ...                                          ...
# 75158   2a29bc6ecf30edb1ad8dbde32aa49a317b4d44f4
# 59972   f776b9408962b9006cfcfe4d6c1794751972cc8e
# 156705  c8c8b2ca1eb76339f69193fdac33d735c864215c
# 15337   3e7f9ee1b5683640d73a4316fb4b0ad5eac5b8a2
# 4782    d39058000707f617cd405629f9bc7f17da7b414a
#
#                                                       url partition  \
# 44793   https://github.com/b3dgs/lionengine/blob/cac3d...     train
# 114654  https://github.com/nguyenq/tess4j/blob/cfcd4a8...     train
# 50192   https://github.com/hazelcast/hazelcast/blob/8c...     train
# 63791   https://github.com/Netflix/conductor/blob/78fa...     train
# 61049   https://github.com/deeplearning4j/deeplearning...     train
# ...                                                   ...       ...
# 75158   https://github.com/facebookarchive/hadoop-20/b...     train
# 59972   https://github.com/apache/incubator-druid/blob...     train
# 156705  https://github.com/classgraph/classgraph/blob/...     train
# 15337   https://github.com/exoplatform/jcr/blob/3e7f9e...     train
# 4782    https://github.com/openengsb/openengsb/blob/d3...     train
#
#                                                       ast  \
# 44793   MethodDeclaration Modifier public static Basic...
# 114654  MethodDeclaration Modifier public static Refer...
# 50192   MethodDeclaration ReferenceType AcquireResult ...
# 63791   MethodDeclaration Modifier public Annotation S...
# 61049   MethodDeclaration Modifier public static asser...
# ...                                                   ...
# 75158   MethodDeclaration Modifier protected setUserJo...
# 59972   MethodDeclaration Modifier private trimZeros L...
# 156705  MethodDeclaration Modifier static ReferenceTyp...
# 15337   MethodDeclaration Modifier private postDelete ...
# 4782    MethodDeclaration Modifier protected Reference...
#
#                                                       des  \
# 44793                        Compares two boolean values.
# 114654  Adds a new DropTargetListener (UNICAST SOURCE)...
# 50192   Adds a new DropTargetListener (UNICAST SOURCE)...
# 63791   Polls this queue to see if a reference object ...
# 61049   Returns a list of MemoryManagerMXBean objects ...
# ...                                                   ...
# 75158   Adds a new DropTargetListener (UNICAST SOURCE)...
# 59972
# 156705  Returns an empty list (immutable). Provides th...
# 15337
# 4782            Returns the runtime class of this Object.
#
#                                                   ast_des
# 44793   MethodDeclaration Modifier public static Basic...
# 114654  MethodDeclaration Modifier public static Refer...
# 50192   MethodDeclaration ReferenceType AcquireResult ...
# 63791   MethodDeclaration Modifier public Annotation S...
# 61049   MethodDeclaration Modifier public static asser...
# ...                                                   ...
# 75158   MethodDeclaration Modifier protected setUserJo...
# 59972   MethodDeclaration Modifier private trimZeros L...
# 156705  MethodDeclaration Modifier static ReferenceTyp...
# 15337   MethodDeclaration Modifier private postDelete ...
# 4782    MethodDeclaration Modifier protected Reference...
#
# [164814 rows x 15 columns]

# %%
train_data_backup = train_data * 1
train_data["ast"] =  train_data.ast.str.replace('[^\x00-\x7F]','')
train_data["des"] =  train_data.des.str.replace('[^\x00-\x7F]','')
train_data["ast_des"] =  train_data.ast_des.str.replace('[^\x00-\x7F]','')

# %%
train_data.to_csv(path_or_buf='/data/code/represent-code-in-human/data/code-summarization-enhanced-full/train.csv',
                    header=0, index=False)

# %%
train_data.to_json(path_or_buf='/data/code/represent-code-in-human/data/code-summarization-enhanced-full/train.jsonl',
                     orient='records', lines=True)
# Out:
#                                  repo  \
# 44793                b3dgs/lionengine
# 114654                 nguyenq/tess4j
# 50192             hazelcast/hazelcast
# 63791               Netflix/conductor
# 61049   deeplearning4j/deeplearning4j
# ...                               ...
# 75158       facebookarchive/hadoop-20
# 59972          apache/incubator-druid
# 156705          classgraph/classgraph
# 15337                 exoplatform/jcr
# 4782              openengsb/openengsb
#
#                                                      path  \
# 44793   lionengine-core/src/main/java/com/b3dgs/lionen...
# 114654  src/main/java/net/sourceforge/tess4j/util/Util...
# 50192   hazelcast/src/main/java/com/hazelcast/cp/inter...
# 63791   core/src/main/java/com/netflix/conductor/servi...
# 61049   nd4j/nd4j-backends/nd4j-api-parent/nd4j-api/sr...
# ...                                                   ...
# 75158   src/contrib/hive-streaming/src/java/org/apache...
# 59972   extendedset/src/main/java/org/apache/druid/ext...
# 156705  src/main/java/io/github/classgraph/ClassTypeSi...
# 15337   exo.jcr.ext.services/src/main/java/org/exoplat...
# 4782    components/edbi/hook/src/main/java/org/openeng...
#
#                                     func_name  \
# 44793                    UtilMath.getDistance
# 114654                  Utils.getConstantName
# 50192                   RaftSemaphore.acquire
# 63791               TaskServiceImpl.batchPoll
# 61049   WorkspaceUtils.assertNoWorkspacesOpen
# ...                                       ...
# 75158           StreamJob.setUserJobConfProps
# 59972                    ConciseSet.trimZeros
# 156705               ClassTypeSignature.parse
# 15337             GroupHandlerImpl.postDelete
# 4782               CommitConverter.mapByClass
#
#                                           original_string language  \
# 44793   public static double getDistance(double x1, do...     java
# 114654  public static String getConstantName(Object va...     java
# 50192   AcquireResult acquire(AcquireInvocationKey key...     java
# 63791   @Service\n    public List<Task> batchPoll(Stri...     java
# 61049   public static void assertNoWorkspacesOpen(Stri...     java
# ...                                                   ...      ...
# 75158   protected void setUserJobConfProps(boolean doE...     java
# 59972   private void trimZeros()\r\n  {\r\n    // loop...     java
# 156705  static ClassTypeSignature parse(final String t...     java
# 15337   private void postDelete(Group group) throws Ex...     java
# 4782    protected Map<Class<?>, List<OpenEngSBModel>> ...     java
#
#                                                      code  \
# 44793   public static double getDistance(double x1, do...
# 114654  public static String getConstantName(Object va...
# 50192   AcquireResult acquire(AcquireInvocationKey key...
# 63791   @Service\n    public List<Task> batchPoll(Stri...
# 61049   public static void assertNoWorkspacesOpen(Stri...
# ...                                                   ...
# 75158   protected void setUserJobConfProps(boolean doE...
# 59972   private void trimZeros()\r\n  {\r\n    // loop...
# 156705  static ClassTypeSignature parse(final String t...
# 15337   private void postDelete(Group group) throws Ex...
# 4782    protected Map<Class<?>, List<OpenEngSBModel>> ...
#
#                                               code_tokens  \
# 44793   [public, static, double, getDistance, (, doubl...
# 114654  [public, static, String, getConstantName, (, O...
# 50192   [AcquireResult, acquire, (, AcquireInvocationK...
# 63791   [@, Service, public, List, <, Task, >, batchPo...
# 61049   [public, static, void, assertNoWorkspacesOpen,...
# ...                                                   ...
# 75158   [protected, void, setUserJobConfProps, (, bool...
# 59972   [private, void, trimZeros, (, ), {, // loop ov...
# 156705  [static, ClassTypeSignature, parse, (, final, ...
# 15337   [private, void, postDelete, (, Group, group, )...
# 4782    [protected, Map, <, Class, <, ?, >, ,, List, <...
#
#                                                 docstring  \
# 44793   Get distance from point to area.\n\n@param x1 ...
# 114654  Gets user-friendly name of the public static f...
# 50192   Assigns permits to the endpoint, if sufficient...
# 63791   Batch Poll for a task of a certain type.\n\n@p...
# 61049   Assert that no workspaces are currently open\n...
# ...                                                   ...
# 75158   This method sets the user jobconf variable spe...
# 59972                              Removes trailing zeros
# 156705  Parse a class type signature or class type des...
# 15337   Notifying listeners after group deletion.\n\n@...
# 4782    Groups all models in the given collection by t...
#
#                                          docstring_tokens  \
# 44793           [Get, distance, from, point, to, area, .]
# 114654  [Gets, user, -, friendly, name, of, the, publi...
# 50192   [Assigns, permits, to, the, endpoint, if, suff...
# 63791   [Batch, Poll, for, a, task, of, a, certain, ty...
# 61049   [Assert, that, no, workspaces, are, currently,...
# ...                                                   ...
# 75158   [This, method, sets, the, user, jobconf, varia...
# 59972                          [Removes, trailing, zeros]
# 156705  [Parse, a, class, type, signature, or, class, ...
# 15337   [Notifying, listeners, after, group, deletion, .]
# 4782    [Groups, all, models, in, the, given, collecti...
#
#                                              sha  \
# 44793   cac3d5578532cf11724a737b9f09e71bf9995ab2
# 114654  cfcd4a8a44042f150b4aaf7bdf5ffc485a2236e1
# 50192   8c4bc10515dbbfb41a33e0302c0caedf3cda1baf
# 63791   78fae0ed9ddea22891f9eebb96a2ec0b2783dca0
# 61049   effce52f2afd7eeb53c5bcca699fcd90bd06822f
# ...                                          ...
# 75158   2a29bc6ecf30edb1ad8dbde32aa49a317b4d44f4
# 59972   f776b9408962b9006cfcfe4d6c1794751972cc8e
# 156705  c8c8b2ca1eb76339f69193fdac33d735c864215c
# 15337   3e7f9ee1b5683640d73a4316fb4b0ad5eac5b8a2
# 4782    d39058000707f617cd405629f9bc7f17da7b414a
#
#                                                       url partition  \
# 44793   https://github.com/b3dgs/lionengine/blob/cac3d...     train
# 114654  https://github.com/nguyenq/tess4j/blob/cfcd4a8...     train
# 50192   https://github.com/hazelcast/hazelcast/blob/8c...     train
# 63791   https://github.com/Netflix/conductor/blob/78fa...     train
# 61049   https://github.com/deeplearning4j/deeplearning...     train
# ...                                                   ...       ...
# 75158   https://github.com/facebookarchive/hadoop-20/b...     train
# 59972   https://github.com/apache/incubator-druid/blob...     train
# 156705  https://github.com/classgraph/classgraph/blob/...     train
# 15337   https://github.com/exoplatform/jcr/blob/3e7f9e...     train
# 4782    https://github.com/openengsb/openengsb/blob/d3...     train
#
#                                                       ast  \
# 44793   MethodDeclaration Modifier public static Basic...
# 114654  MethodDeclaration Modifier public static Refer...
# 50192   MethodDeclaration ReferenceType AcquireResult ...
# 63791   MethodDeclaration Modifier public Annotation S...
# 61049   MethodDeclaration Modifier public static asser...
# ...                                                   ...
# 75158   MethodDeclaration Modifier protected setUserJo...
# 59972   MethodDeclaration Modifier private trimZeros L...
# 156705  MethodDeclaration Modifier static ReferenceTyp...
# 15337   MethodDeclaration Modifier private postDelete ...
# 4782    MethodDeclaration Modifier protected Reference...
#
#                                                       des  \
# 44793                        Compares two boolean values.
# 114654  Adds a new DropTargetListener (UNICAST SOURCE)...
# 50192   Adds a new DropTargetListener (UNICAST SOURCE)...
# 63791   Polls this queue to see if a reference object ...
# 61049   Returns a list of MemoryManagerMXBean objects ...
# ...                                                   ...
# 75158   Adds a new DropTargetListener (UNICAST SOURCE)...
# 59972
# 156705  Returns an empty list (immutable). Provides th...
# 15337
# 4782            Returns the runtime class of this Object.
#
#                                                   ast_des
# 44793   MethodDeclaration Modifier public static Basic...
# 114654  MethodDeclaration Modifier public static Refer...
# 50192   MethodDeclaration ReferenceType AcquireResult ...
# 63791   MethodDeclaration Modifier public Annotation S...
# 61049   MethodDeclaration Modifier public static asser...
# ...                                                   ...
# 75158   MethodDeclaration Modifier protected setUserJo...
# 59972   MethodDeclaration Modifier private trimZeros L...
# 156705  MethodDeclaration Modifier static ReferenceTyp...
# 15337   MethodDeclaration Modifier private postDelete ...
# 4782    MethodDeclaration Modifier protected Reference...
#
# [164814 rows x 15 columns]

# %%
data_test = pd.read_json(path_or_buf='/data/code/represent-code-in-human/data/code-summarization-enhanced-full/test.jsonl', lines=True)
data_test
# Out:
#                                 repo  \
# 0                    Unidata/thredds
# 1         orientechnologies/orientdb
# 2                intellimate/IzouSDK
# 3         orientechnologies/orientdb
# 4           streamsets/datacollector
# ...                              ...
# 10947                     Axway/iron
# 10948  lessthanoptimal/GeoRegression
# 10949            intellimate/IzouSDK
# 10950        jboss/jboss-common-core
# 10951                Unidata/thredds
#
#                                                     path  \
# 0        cdm/src/main/java/ucar/unidata/util/Format.java
# 1      core/src/main/java/com/orientechnologies/orien...
# 2      src/main/java/org/intellimate/izou/sdk/framewo...
# 3      object/src/main/java/com/orientechnologies/ori...
# 4      cluster-bootstrap-api/src/main/java/com/stream...
# ...                                                  ...
# 10947  iron-core/src/main/java/io/axway/iron/core/int...
# 10948  main/src/georegression/geometry/UtilLine2D_F64...
# 10949  src/main/java/org/intellimate/izou/sdk/framewo...
# 10950  src/main/java/org/jboss/util/property/Property...
# 10951  dap4/d4lib/src/main/java/dap4/dap4lib/DSPPrint...
#
#                                           func_name  \
# 0                                        Format.tab
# 1      OBinarySerializerFactory.getObjectSerializer
# 2                                  TrackInfo.export
# 3      ODocumentFieldHandlingStrategyFactory.create
# 4                    BootstrapClusterStreaming.main
# ...                                             ...
# 10947                   StorePersistence.loadStores
# 10948                        UtilLine2D_F64.convert
# 10949                  PresenceConstant.setPresence
# 10950                                  Property.set
# 10951              DSPPrinter.printCompoundInstance
#
#                                          original_string language  \
# 0      public static void tab(StringBuffer sbuff, int...     java
# 1      @SuppressWarnings("unchecked")\n  public <T> O...     java
# 2      public HashMap<String, Object> export() {\n   ...     java
# 3      public ODocumentFieldHandlingStrategy create(i...     java
# 4      public static void main(String[] args) throws ...     java
# ...                                                  ...      ...
# 10947  Optional<BigInteger> loadStores(Function<Strin...     java
# 10948  public static LinePolar2D_F64 convert( LineGen...     java
# 10949  public void setPresence(boolean present) {\n  ...     java
# 10950  public static String set(String name, String v...     java
# 10951  protected void\n    printCompoundInstance(Data...     java
#
#                                                     code  \
# 0      public static void tab(StringBuffer sbuff, int...
# 1      @SuppressWarnings("unchecked")\n  public <T> O...
# 2      public HashMap<String, Object> export() {\n   ...
# 3      public ODocumentFieldHandlingStrategy create(i...
# 4      public static void main(String[] args) throws ...
# ...                                                  ...
# 10947  Optional<BigInteger> loadStores(Function<Strin...
# 10948  public static LinePolar2D_F64 convert( LineGen...
# 10949  public void setPresence(boolean present) {\n  ...
# 10950  public static String set(String name, String v...
# 10951  protected void\n    printCompoundInstance(Data...
#
#                                              code_tokens  \
# 0      [public, static, void, tab, (, StringBuffer, s...
# 1      [@, SuppressWarnings, (, "unchecked", ), publi...
# 2      [public, HashMap, <, String, ,, Object, >, exp...
# 3      [public, ODocumentFieldHandlingStrategy, creat...
# 4      [public, static, void, main, (, String, [, ], ...
# ...                                                  ...
# 10947  [Optional, <, BigInteger, >, loadStores, (, Fu...
# 10948  [public, static, LinePolar2D_F64, convert, (, ...
# 10949  [public, void, setPresence, (, boolean, presen...
# 10950  [public, static, String, set, (, String, name,...
# 10951  [protected, void, printCompoundInstance, (, Da...
#
#                                                docstring  \
# 0      Blank fill sbuff with blanks, until position t...
# 1      Obtain OBinarySerializer realization for the O...
# 2      exports the TrackInfo to a Hashmap\n@return a ...
# 3      Creates a new instance of the requested strate...
# 4      Bootstrapping the Driver which starts a Spark ...
# ...                                                  ...
# 10947  Load the stores.\n\n@param entityStoresByStore...
# 10948  Converts a line from general to polar.\n\n@par...
# 10949  sets the presence\n@param present true for pre...
# 10950  Set a property\n\n@param name    Property name...
# 10951  Print a single structure or sequence or record...
#
#                                         docstring_tokens  \
# 0      [Blank, fill, sbuff, with, blanks, until, posi...
# 1      [Obtain, OBinarySerializer, realization, for, ...
# 2              [exports, the, TrackInfo, to, a, Hashmap]
# 3      [Creates, a, new, instance, of, the, requested...
# 4      [Bootstrapping, the, Driver, which, starts, a,...
# ...                                                  ...
# 10947                             [Load, the, stores, .]
# 10948   [Converts, a, line, from, general, to, polar, .]
# 10949                              [sets, the, presence]
# 10950                                 [Set, a, property]
# 10951  [Print, a, single, structure, or, sequence, or...
#
#                                             sha  \
# 0      d2d68f9eee87f345625211324d71d5dc3e162ee1
# 1      d970b12033f0462f0239ea0ad8ed41207e6e26f1
# 2      bc8705ad48a6ca12a722f2b787be435949fa5d08
# 3      d970b12033f0462f0239ea0ad8ed41207e6e26f1
# 4      ea63245ea14d59d5229248387f0628f46131eae5
# ...                                         ...
# 10947  387ec6d43d2353f857d510dd29f93a06a8db9069
# 10948  c067cd44a4e95bd826119f6e658bd82386ef289f
# 10949  bc8705ad48a6ca12a722f2b787be435949fa5d08
# 10950  c191bb18db83fa106c6913cf34ed47989b65dc97
# 10951  d2d68f9eee87f345625211324d71d5dc3e162ee1
#
#                                                      url partition  \
# 0      https://github.com/Unidata/thredds/blob/d2d68f...      test
# 1      https://github.com/orientechnologies/orientdb/...      test
# 2      https://github.com/intellimate/IzouSDK/blob/bc...      test
# 3      https://github.com/orientechnologies/orientdb/...      test
# 4      https://github.com/streamsets/datacollector/bl...      test
# ...                                                  ...       ...
# 10947  https://github.com/Axway/iron/blob/387ec6d43d2...      test
# 10948  https://github.com/lessthanoptimal/GeoRegressi...      test
# 10949  https://github.com/intellimate/IzouSDK/blob/bc...      test
# 10950  https://github.com/jboss/jboss-common-core/blo...      test
# 10951  https://github.com/Unidata/thredds/blob/d2d68f...      test
#
#                                                      des  \
# 0      Sets the length of this file. Returns the curr...
# 1        Adds a new DropTargetListener (UNICAST SOURCE).
# 2      Called by the context acceptor to process a to...
# 3      Adds a new DropTargetListener (UNICAST SOURCE)...
# 4      Awaits termination of the group. Determines th...
# ...                                                  ...
# 10947  Adds component-listener-a with component-liste...
# 10948  Returns the correctly rounded positive square ...
# 10949
# 10950  Sets the system property indicated by the spec...
# 10951  Adds a new DropTargetListener (UNICAST SOURCE)...
#
#                                                      ast  \
# 0      MethodDeclaration Modifier public static tab F...
# 1      MethodDeclaration Modifier public Annotation S...
# 2      MethodDeclaration Modifier public ReferenceTyp...
# 3      MethodDeclaration Modifier public ReferenceTyp...
# 4      MethodDeclaration Modifier public static main ...
# ...                                                  ...
# 10947  MethodDeclaration ReferenceType Optional TypeA...
# 10948  MethodDeclaration Modifier public static Refer...
# 10949  MethodDeclaration Modifier public setPresence ...
# 10950  MethodDeclaration Modifier public static Refer...
# 10951  MethodDeclaration Modifier protected printComp...
#
#                                                  ast_des
# 0      MethodDeclaration Modifier public static tab F...
# 1      MethodDeclaration Modifier public Annotation S...
# 2      MethodDeclaration Modifier public ReferenceTyp...
# 3      MethodDeclaration Modifier public ReferenceTyp...
# 4      MethodDeclaration Modifier public static main ...
# ...                                                  ...
# 10947  MethodDeclaration ReferenceType Optional TypeA...
# 10948  MethodDeclaration Modifier public static Refer...
# 10949  MethodDeclaration Modifier public setPresence ...
# 10950  MethodDeclaration Modifier public static Refer...
# 10951  MethodDeclaration Modifier protected printComp...
#
# [10952 rows x 15 columns]

# %%
train_data['code'][0: 5]
# Out:
# 44793     public static double getDistance(double x1, do...
# 114654    public static String getConstantName(Object va...
# 50192     AcquireResult acquire(AcquireInvocationKey key...
# 63791     @Service\n    public List<Task> batchPoll(Stri...
# 61049     public static void assertNoWorkspacesOpen(Stri...
# Name: code, dtype: object

# %%
train_data['ast_des'][0: 5]
# Out:
# 44793     MethodDeclaration Modifier public static Basic...
# 114654    MethodDeclaration Modifier public static Refer...
# 50192     MethodDeclaration ReferenceType AcquireResult ...
# 63791     MethodDeclaration Modifier public Annotation S...
# 61049     MethodDeclaration Modifier public static asser...
# Name: ast_des, dtype: object

# %%
train_df['ast'][1]
# Out:
# 'MethodDeclaration Modifier public static ReferenceType String getConstantName FormalParameter ReferenceType Object value FormalParameter ReferenceType Class c ForStatement EnhancedForControl VariableDeclaration ReferenceType Field VariableDeclarator f MethodInvocation c getDeclaredFields BlockStatement LocalVariableDeclaration BasicType int VariableDeclarator mod MethodInvocation f getModifiers IfStatement BinaryOperation && BinaryOperation && MethodInvocation Modifier MemberReference mod isStatic MethodInvocation Modifier MemberReference mod isPublic MethodInvocation Modifier MemberReference mod isFinal BlockStatement TryStatement IfStatement MethodInvocation f MethodInvocation MemberReference value equals Literal null get BlockStatement ReturnStatement MethodInvocation f getName CatchClause CatchClauseParameter IllegalAccessException e ReturnStatement MethodInvocation String MemberReference value valueOf ReturnStatement MethodInvocation String MemberReference value valueOf'
